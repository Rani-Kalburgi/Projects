# %%
tasks = []

while True:
    print("\n===== To-Do List Menu =====")
    print("1. Add a task")
    print("2. Remove a task")
    print("3. View tasks")
    print("4. Exit")

    choice = input("Enter your choice: ")

    if choice == '1':
        tasks.append(input("Enter the task: "))
    elif choice == '2':
        task_to_remove = input("Enter the task to remove: ")
        if task_to_remove in tasks:
            tasks.remove(task_to_remove)
        else:
            print("Task not found!")
    elif choice == '3':
        print("\nYour To-Do List:")
        for idx, task in enumerate(tasks, start=1):
            print(f"{idx}. {task}")
    elif choice == '4':
        print("Exiting program. Goodbye!")
        break
    else:
        print("Invalid choice. Please choose again.")
# Out:
# ===== To-Do List Menu =====
# 1. Add a task
# 2. Remove a task
# 3. View tasks
# 4. Exit
# Enter your choice: 1
# Enter the task: bake
#
# ===== To-Do List Menu =====
# 1. Add a task
# 2. Remove a task
# 3. View tasks
# 4. Exit
# Enter your choice: 1
# Enter the task: paint
#
# ===== To-Do List Menu =====
# 1. Add a task
# 2. Remove a task
# 3. View tasks
# 4. Exit
# Enter your choice: 1
# Enter the task: dance
#
# ===== To-Do List Menu =====
# 1. Add a task
# 2. Remove a task
# 3. View tasks
# 4. Exit
# Enter your choice: 1
# Enter the task: sing
#
# ===== To-Do List Menu =====
# 1. Add a task
# 2. Remove a task
# 3. View tasks
# 4. Exit
# Enter your choice: 3
#
# Your To-Do List:
# 1. bake
# 2. paint
# 3. dance
# 4. sing
#
# ===== To-Do List Menu =====
# 1. Add a task
# 2. Remove a task
# 3. View tasks
# 4. Exit
# Enter your choice: 2
# Enter the task to remove: paint
#
# ===== To-Do List Menu =====
# 1. Add a task
# 2. Remove a task
# 3. View tasks
# 4. Exit
# Enter your choice: 3
#
# Your To-Do List:
# 1. bake
# 2. dance
# 3. sing
#
# ===== To-Do List Menu =====
# 1. Add a task
# 2. Remove a task
# 3. View tasks
# 4. Exit
